# %% [markdown]
# # Part 1a: Navigating public databases and resources
#
# The purpose of Part 1 is to learn how to navigate and use public databases and resources to understand the inheritance pattern, genomic architecture, and pathogenesis pathway of genetic diseases.
#
# ---
#
# **IMPORTANT:**
#
# - Your group is assigned to a gene/variant of interest \(**G/VOI**\) from a genetic disease \(that you have selected as a group\).
# - Complete and submit Lab 1 individually using this gene/variant of interest and disease.
# - You may work together as a group to verify the information you've collected across the databases.
#
# ---
#
# Here is a table of the resources we will be using in Lab 1. This is a non-comprehensive table of publicly available resources, but we will use the following to get started.
#
# | Database | Purpose |
# |---------|-------|
# | [UCSC Genome Browser](http://genome.ucsc.edu/) | Provides genomic and epigenomic data, including visualization tools for genome annotations. |
# | [OMIM](https://www.omim.org/) | A database of human genes and genetic disorders. Use this to investigate gene\-disease relationships and find information on genetic disorders. |
# | [GeneCards](https://www.genecards.org/)| Integrates information about genes, their functions, expression, and and relevance to diseases. |
# | [GeneReviews](https://www.ncbi.nlm.nih.gov/books/NBK1116/)| Expert-authored summaries on genetic conditions, including diagnostic and treatment guidelines.|

# %% [markdown]
# ## Exercise 1: UCSC Genome Browser
#
# Genome browsers *integrate genomic sequence* and *annotation data* from different sources and provide a platform to search, browse, retrieve, and analyze genomic data. They differ from ordinary biological databases in that they display data in a graphical format, with genome coordinates on one axis with annotations or space-filling graphics to show analyses of the genes, such as the frequency of the genes, their expression profiles, etc.
#
# ### 1a: Find your G/VOI \(1.5 pt\)
#
# **Instructions:** Complete the following using your **G/VOI**
#
# 1. Go to the **UCSC Genome Browser**, center the track on your gene or variant of interest. If you are assigned a genetic variant, include the entire gene that the variant belongs to.
# 2. Locate the track showing the exons, introns, and direction of strands like the image below.
#    - The direction of arrows indicates the 5’ &gt; 3’ direction of a gene.
#    - Each row of the blue genes is an isoform.
#    - <img src="https://cocalc.com/blobs/image.png?uuid=3c77532d-01e6-400d-9744-ee607c6d7d91"   width="609.977px"  height="176.281px"  style="object-fit:cover"/>
#
# **In the code cell below**:
#
# 1. \(0.5 pt\) Store the location of the gene \(transcript including UTR's\) as shown in UCSC Genome Browser as a string in the variable `gene_location`.
# 2. \(0.5 pt\) Store the strand direction as a string in the variable `strand_direction`.
# 3. \(0.5 pt\) Store the number of exons as an integer in the variable `total_exon`.
#
# Here is an example for the gene KMT2A:
#
# ```py
# gene_location = "chr11:118436492-118526832"
# strand_direction = "+"
# total_exon = 36
# ```

# %%
gene_location = "chr19:11,089,463-11,133,820"
strand_direction = "+"
total_exon = 18

# %% [markdown]
# ### 1b: Locate the regulatory elements using ENCODE tracks \(2 pt\)
#
# 1. Add the **ENCODE track** to your UCSC Genome Browser.
#
# <img src="https://cocalc.com/blobs/image%207.png?uuid=7c2748c9-b678-43d4-a717-b10eae224138"   width="557.977px"  height="65.0078px"  style="object-fit:cover"/>
# <img src="https://cocalc.com/blobs/image%208.png?uuid=9fd3cb5b-472b-4215-9310-3573608363e0"   width="550.977px"  height="127.656px"  style="object-fit:cover"/>
#
# 2. \(2 pt\) **In 2\-3 sentences, explain the locations of the peaks in the H3K Tracks and DNase I Hypersensitivity Track. Based on your knowledge of the gene structure, why do you see the peaks at these locations?**

# %% [markdown]
# ###
# **ANSWER:**
# H3K acetylation and methylation peaks span exon 1 and into intron 1 with some peaks at exon 18. DNase Signal show highest sensitivity at and around exon 1. This makes sense because this is where UTR regions for expression would be located/open chromatin.

# %% [markdown]
# ### 1c: Find tissue\-specific gene expression using GTEx V8 track \(2 pt\)
#
# **Instructions**:
#
# 1. Add the **GTEx Gene v8 track** to your UCSC Genome Browser.<img src="https://cocalc.com/blobs/image%205.png?uuid=0e13695d-3b79-4035-ab34-ca9673e97751"  alt="image"  width="619.977px"  height="74.078px"  style="object-fit:cover"/>
# 2. Click on the added track to find the tissue\-specific gene expression.
# 3. **In two sentences, describe the tissues in which the gene expression are upregulated and downregulated based on the GTEx gene expression plot** <u>**for your assigned G/VOI**</u>. Your plot should have the same x\- and y\-axes as the figure below.<img src="https://cocalc.com/blobs/image%206.png?uuid=cbf7b23d-e618-4d2f-9d88-ff91c41be22a"   width="588.977px"  height="329.82000000000005px"  style="object-fit:cover"/>

# %% [markdown]
# ###
# **ANSWER:**
# The tissues that are upregulated are Adrinal Gland, Lungs and Ovaries. The tissue that are down regulated is derived from the CNS (specifically brain)

# %% [markdown]
# ### 1d: Find conserved regions using conservation tracks \(2 pt\)
#
# **Instructions:**
#
# 1. Add the **Conservation track** to your UCSC Genome Browser.
#    <img src="https://cocalc.com/blobs/paste-0.02950513192582105?uuid=756d2919-d302-4b7c-b047-c2cfede6b485"   width="620.977px"  height="66.859px"  style="object-fit:cover"/>
#    <img src="https://cocalc.com/blobs/paste-0.46117091136727173?uuid=c1c66672-3476-44fd-a85a-7bc8367b4f3b"   width="618.977px"  height="158.695px"  style="object-fit:cover"/>
# 2. Add the **OMIM track** to locate the disease variants.
#    <img src="https://cocalc.com/blobs/paste-0.42838156988337284?uuid=709767a2-fbfd-4133-95ae-3c2ccf6ed869"   width="653.977px"  height="66.4844px"  style="object-fit:cover"/>
#    <img src="https://cocalc.com/blobs/paste-0.3626376626169652?uuid=657a011e-cba2-4129-8bf3-feed7768dcea"   width="650.977px"  height="194.22699999999998px"  style="object-fit:cover"/>
#
# **Provide the answer using your** <u>**G/VOI**</u> **in the markdown cell below:**
#
# - \(0.5 pt\) List one disease variant that lies in a region with high conservation score.
# - \(0.5 pt\) List one disease variant that is in a region with low conservation score.
# - \(1 pt\) What does the conservation score suggest about the rate of evolution for these disease variant

# %% [markdown]
# ###
# **ANSWER**
# - High conservation region -> 606945.0015 FH FRENCH CANADIAN 2 (rs28942083)
# - Low conservation region -> 606945.0055 FH AARHUS (rs397509365,rs875989944) *still relativily high conservation
# - Inverse relationship between conservation score and rate of evolution, regions with high conservation show low rate of evolution

# %% [markdown]
# ### 1e: Screenshot of your UCSC Genome Browser \(1 pt\)
#
# **Instructions:**
#
# - Attach a screenshot of your UCSC Genome Browser in the markdown cell below.
# - Include all of the tracks mentioned in Exercise 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 2: OMIM Database
#
# **Instructions:**
#
# 1. Go to [OMIM](https://www.omim.org/) and look up your **G/VOI**.
#    <img src="https://cocalc.com/blobs/paste-0.6653423566625452?uuid=09b4793d-840e-4d3a-9ca8-5e7af7b40d37"   width="431.977px"  height="116.945px"  style="object-fit:cover"/>
#
# 2. Select "Gene Map Table"
#    <img src="https://cocalc.com/blobs/paste-0.9563376131075116?uuid=fc9beb4b-7bc6-48fc-bb11-3a4322cef66e"   width="785.977px"  height="93.43px"  style="object-fit:cover"/>
#
# 3. Click on the **Gene/Locus MIM** and **Phenotype MIM** numbers to find clinically relevant information about your **G/VOI**.<img src="https://cocalc.com/blobs/paste-0.18438085791551062?uuid=305735e0-8080-4dd3-8ab6-8a6dc115f686"   width="963.977px"  height="320.203px"  style="object-fit:cover"/>
#
# **Provide the answer using your** <u>**G/VOI**</u> **in the markdown cell below:**
#
# - \(0.5 pt\) What is the inheritance pattern of your disease?
# - \(0.5 pt\) What is the most common type of allelic variant associated with your GVOI?

# %% [markdown]
# ###
# **ANSWER**
# - Inherited in both a autosomal dominant and recessive manner
# - Variants in the LDLR gene are highly variable and most common variant is dictaed by geography/population (ex. Deletion of the promoter and exon 1 of the LDLR gene is the mutation most commonly found in French Canadian ( ~60% ) cases of FH)

# %% [markdown]
# ## Exercise 3: Pathogenesis pathway (2 pt)
#
# Based on the information in the first two exercises and accessible information in GeneCards and GeneReviews, describe the pathogenesis pathway of your assigned disease. Specifically, explain how your GVOI may contribute to the clinical phenotype of the disease. Cite the database\(s\) from which you found the information.

# %% [markdown]
# Using the example provided in excersize 2, when a deletion is presesent in the promotor region of LDLR results in no transcription of the LDLR gene, decreasing overall expression. The function of LDLR is as a surface receptor for endocytosis of low density lipoprotein/cholesterol (LDL) into the cell. The fact that organs with high flexibility (lungs) or steroid hormone production (adrinal gland and ovaries) express high levels of LDL indicates that decreased expression of LDLR results in lower results in less uptake of LDL by tissues and more LDL that is free floating
